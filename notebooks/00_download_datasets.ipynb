# %%
import kagglehub
from pathlib import Path
import shutil

# %%
DATA_DIR = Path('data/raw')

# %%
def download_sentiment_mental_health():
    DATA_DIR.mkdir(parents=True, exist_ok=True)
    handle = "suchintikasarkar/sentiment-analysis-for-mental-health"
    local_path = kagglehub.dataset_download(handle)
    print("Downloaded dataset", local_path)

# %%
def main():
    download_sentiment_mental_health()

# %%
if __name__ == "__main__":
    main()
# Out:
# Downloaded dataset C:\Users\sksof\.cache\kagglehub\datasets\suchintikasarkar\sentiment-analysis-for-mental-health\versions\1
# Dataset copied to: data\raw\1
